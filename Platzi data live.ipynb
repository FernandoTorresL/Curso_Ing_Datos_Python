# %%
print('Hello, world!')

# %% [markdown]
# ### Esto es un título
# esto es texto y esto es **bold** *italica*

# %%
from datetime import datetime

integer_type = 42
float_type = 3.14159
bool_type = False
hex_type = 0xff
oct_type = 0o23
str_type = 'David'
today = datetime.now()
print (today)
print ('oct:', oct_type)
print ('hex: ', hex_type)
str_type
oct_type

# %%
str_type

# %%
from IPython.display import Image

Image('Atajos Rectangle.png')

# %% [markdown]
# ## Solicitudes a la web

# %%
import requests

response = requests.get('https://www.platzi.com')
response.encoding = 'utf-8'

# %% [markdown]
# response?
#
# response??
#
# print(dir(response))

# %%
print(response.status_code)

# %%
print(response.headers)

# %%
print(response.headers['Content-Type'])

# %%
print(response.text)

# %% [markdown]
# ### Extracción de información del HTML

# %%
import bs4

soup = bs4.BeautifulSoup(response.text, 'html.parser')

print(soup.title.text)

# %%
print(soup.select('meta[name=description]'))

# %%
print(soup.select('meta[name=description]')[0]['content'])

# %%
courses_links = soup.select('div[class=RecentCourses-content] > h3')

courses = [i.text for i in courses_links]

for i in courses:
    print('->', i)

# %% [markdown]
# # Series

# %%
import pandas as pd

series_test = pd.Series([100, 200, 300])

series_test

# %%
series_test2 = pd.Series({1999: 48, 
                          2000: 65, 
                          2001: 89})

series_test2

# %% [markdown]
# # DataFrames

# %% [markdown]
# ## Read data

# %%
frame_test = pd.DataFrame({1999: [74, 38, 39], 
                           2000: [34, 32, 32], 
                           2001: [23, 39, 23]})
frame_test

# %%
frame_test2 = pd.DataFrame([[74, 38, 39], 
                           [34, 32, 32], 
                           [23, 39, 23]], columns=[1999, 2000, 2001])
frame_test2

# %% [markdown]
# # Read data

# %%
import pandas as pd
el_universal = pd.read_csv('web_scrapper_curso_data_eng/eluniversal_2020_08_23x_articles.csv')

type(el_universal)

el_universal
# Out:
#                                                  body  \
# 0   \nLa epidemia de coronavirus registró una nuev...
# 1   \nUna ola de acontecimientos concentrada en un...
# 2   \nLa Ciudad de México mostró una disminución d...
# 3   \nElizabeth Hurley presumió la impresionante f...
# 4   \n\nLos líderes autoritarios acostumbran cambi...
# ..                                                ...
# 69  \nLa fotografía es icónica. El día de la excar...
# 70  \nUna ola de acontecimientos concentrada en un...
# 71  \nLa élite que por generaciones monopolizó el ...
# 72  \n\nEn solidaridad con Nexos\n\n \n\nLa invest...
# 73  \n\nSuperado el berrinche de John Ackerman por...
#
#                               title  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 69          Lo impecable (y ni Pío)
# ...

# %%
el_universal.head()
# Out:
#                                                 body title  \
# 0  \nLa epidemia de coronavirus registró una nuev...   NaN
# 1  \nUna ola de acontecimientos concentrada en un...   NaN
# 2  \nLa Ciudad de México mostró una disminución d...   NaN
# 3  \nElizabeth Hurley presumió la impresionante f...   NaN
# 4  \n\nLos líderes autoritarios acostumbran cambi...   NaN
#
#                                                  url
# 0  https://www.eluniversal.com.mx/mundo/francia-r...
# 1  https://www.eluniversal.com.mx/opinion/roberto...
# 2  https://www.eluniversal.com.mx/metropoli/cdmx/...
# 3  https://www.viveusa.mx/showbiz/elizabeth-hurle...
# 4  https://www.eluniversal.com.mx/opinion/sara-se...

# %%
el_universal.tail()
# Out:
#                                                  body  \
# 69  \nLa fotografía es icónica. El día de la excar...
# 70  \nUna ola de acontecimientos concentrada en un...
# 71  \nLa élite que por generaciones monopolizó el ...
# 72  \n\nEn solidaridad con Nexos\n\n \n\nLa invest...
# 73  \n\nSuperado el berrinche de John Ackerman por...
#
#                               title  \
# 69          Lo impecable (y ni Pío)
# 70                 El país catarsis
# 71         Una oposición sin cabeza
# 72          Teoría de la corrupción
# 73  Partidos ahora van por el Trife
#
#                                                   url
# 69  https://www.eluniversal.com.mx/opinion/sabina-...
# 70  https://www.eluniversal.com.mx/opinion/roberto...
# 71  https://www.eluniversal.com.mx/opinion/lorenzo...
# 72  https://www.eluniversal.com.mx/opinion/francis...
# 73  https://www.eluniversal.com.mx/opinion/periodi...

# %%
pd.options.display.max_rows = 10

el_universal
# Out:
#                                                  body  \
# 0   \nLa epidemia de coronavirus registró una nuev...
# 1   \nUna ola de acontecimientos concentrada en un...
# 2   \nLa Ciudad de México mostró una disminución d...
# 3   \nElizabeth Hurley presumió la impresionante f...
# 4   \n\nLos líderes autoritarios acostumbran cambi...
# ..                                                ...
# 69  \nLa fotografía es icónica. El día de la excar...
# 70  \nUna ola de acontecimientos concentrada en un...
# 71  \nLa élite que por generaciones monopolizó el ...
# 72  \n\nEn solidaridad con Nexos\n\n \n\nLa invest...
# 73  \n\nSuperado el berrinche de John Ackerman por...
#
#                               title  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 69          Lo impecable (y ni Pío)
# ...

# %% [markdown]
# # Class #24 Index and selection

# %%
## dictionary like

el_universal['title']
# Out:
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#                    ...
# 69            Lo impecable (y ni Pío)
# 70                   El país catarsis
# 71           Una oposición sin cabeza
# 72            Teoría de la corrupción
# 73    Partidos ahora van por el Trife
# Name: title, Length: 74, dtype: object

# %%
el_universal[['title', 'url']]
# Out:
#                               title  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 69          Lo impecable (y ni Pío)
# 70                 El país catarsis
# 71         Una oposición sin cabeza
# 72          Teoría de la corrupción
# 73  Partidos ahora van por el Trife
#
#                                                   url
# 0   https://www.eluniversal.com.mx/mundo/francia-r...
# 1   https://www.eluniversal.com.mx/opinion/roberto...
# 2   https://www.eluniversal.com.mx/metropoli/cdmx/...
# 3   https://www.viveusa.mx/showbiz/elizabeth-hurle...
# 4   https://www.eluniversal.com.mx/opinion/sara-se...
# ..                                                ...
# 69  https://www.eluniversal.com.mx/opinion/sabina-...
# 70  https://www.eluniversal.com.mx/opinion/roberto...
# ...

# %%
# Numpy like

el_universal.iloc[0:10]

# %%
el_universal.iloc[66]

# %%
el_universal.iloc[66]['title']

# %%
el_universal.iloc[:5, 0]

# %%
el_universal.loc[:,'body': 'title']
# Out:
#                                                  body  \
# 0   \nLa epidemia de coronavirus registró una nuev...
# 1   \nUna ola de acontecimientos concentrada en un...
# 2   \nLa Ciudad de México mostró una disminución d...
# 3   \nElizabeth Hurley presumió la impresionante f...
# 4   \n\nLos líderes autoritarios acostumbran cambi...
# ..                                                ...
# 69  \nLa fotografía es icónica. El día de la excar...
# 70  \nUna ola de acontecimientos concentrada en un...
# 71  \nLa élite que por generaciones monopolizó el ...
# 72  \n\nEn solidaridad con Nexos\n\n \n\nLa invest...
# 73  \n\nSuperado el berrinche de John Ackerman por...
#
#                               title
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 69          Lo impecable (y ni Pío)
# ...

# %% [markdown]
# # Class #25 Data wrangling

# %%
import pandas as pd
el_universal = pd.read_csv('web_scrapper_curso_data_eng/eluniversal_2020_08_23x_articles.csv')


# 1. Añadir newspaper_uid al DataFrame

#Añadir columna:
el_universal['newspaper_uid'] = 'eluniversal'

el_universal
# Out:
#                                                  body  \
# 0   \nLa epidemia de coronavirus registró una nuev...
# 1   \nUna ola de acontecimientos concentrada en un...
# 2   \nLa Ciudad de México mostró una disminución d...
# 3   \nElizabeth Hurley presumió la impresionante f...
# 4   \n\nLos líderes autoritarios acostumbran cambi...
# ..                                                ...
# 69  \nLa fotografía es icónica. El día de la excar...
# 70  \nUna ola de acontecimientos concentrada en un...
# 71  \nLa élite que por generaciones monopolizó el ...
# 72  \n\nEn solidaridad con Nexos\n\n \n\nLa invest...
# 73  \n\nSuperado el berrinche de John Ackerman por...
#
#                               title  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 69          Lo impecable (y ni Pío)
# ...

# %%
# 2. Obtener el host

# from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                  body  \
# 0   \nLa epidemia de coronavirus registró una nuev...
# 1   \nUna ola de acontecimientos concentrada en un...
# 2   \nLa Ciudad de México mostró una disminución d...
# 3   \nElizabeth Hurley presumió la impresionante f...
# 4   \n\nLos líderes autoritarios acostumbran cambi...
# ..                                                ...
# 69  \nLa fotografía es icónica. El día de la excar...
# 70  \nUna ola de acontecimientos concentrada en un...
# 71  \nLa élite que por generaciones monopolizó el ...
# 72  \n\nEn solidaridad con Nexos\n\n \n\nLa invest...
# 73  \n\nSuperado el berrinche de John Ackerman por...
#
#                               title  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 69          Lo impecable (y ni Pío)
# ...

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx         68
# www.viveusa.mx                  2
# sanluis.eluniversal.com.mx      1
# www.eluniversalqueretaro.mx     1
# oaxaca.eluniversal.com.mx       1
# de10.com.mx                     1
# Name: host, dtype: int64

# %% [markdown]
# # Class #27 Missing data

# %%
el_universal['title']
# Out:
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#                    ...
# 69            Lo impecable (y ni Pío)
# 70                   El país catarsis
# 71           Una oposición sin cabeza
# 72            Teoría de la corrupción
# 73    Partidos ahora van por el Trife
# Name: title, Length: 74, dtype: object

# %%
# 3. Rellenar datos faltantes

missing_titles_mask = el_universal['title'].isna()

missing_titles_mask
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# Name: title, Length: 74, dtype: bool

# %%
missing_titles_mask.value_counts()
# Out:
# False    49
# True     25
# Name: title, dtype: int64

# %%
el_universal[missing_titles_mask]['url']
# Out:
# 0     https://www.eluniversal.com.mx/mundo/francia-r...
# 1     https://www.eluniversal.com.mx/opinion/roberto...
# 2     https://www.eluniversal.com.mx/metropoli/cdmx/...
# 3     https://www.viveusa.mx/showbiz/elizabeth-hurle...
# 4     https://www.eluniversal.com.mx/opinion/sara-se...
#                             ...
# 55    https://www.viveusa.mx/showbiz/stassie-karanik...
# 56    https://de10.com.mx/vivir-bien/fer-sagreeb-el-...
# 57    https://www.eluniversalqueretaro.mx/portada/es...
# 58    https://sanluis.eluniversal.com.mx/sociedad/21...
# 59    https://oaxaca.eluniversal.com.mx/sociedad/21-...
# Name: url, Length: 25, dtype: object

# %%
el_universal[missing_titles_mask]['url'].str.extract(r'(?P<missing_titles>[^/]+)$')
# Out:
#                                        missing_titles
# 0   francia-registra-mas-de-4-mil-800-casos-de-cor...
# 1                                    el-pais-catarsis
# 2   baja-23-incidencia-delictiva-en-cdmx-segun-cif...
# 3   elizabeth-hurley-arrasa-en-instagram-con-bikin...
# 4           metafora-16-el-fin-de-la-historia-oficial
# ..                                                ...
# 55  stassie-karanikolau-amiga-de-kylie-jenner-se-l...
# 56  fer-sagreeb-el-conductor-mexicano-que-bajo-55-...
# 57                 estado-registra-84-muertes-diarias
# 58  tu-hermano-ya-no-tenia-pulmones-el-covid-19-se...
# 59  identidad-oaxaquena-llevo-alan-al-jazz-ahora-e...
#
# [25 rows x 1 columns]

# %%
missing_titles = (el_universal[missing_titles_mask]['url']
        .str.extract(r'(?P<missing_titles>[^/]+)$')
        .applymap(lambda title: title.split('-'))
        .applymap(lambda title_word_list: ' '.join(title_word_list)))

missing_titles
# Out:
#                                        missing_titles
# 0   francia registra mas de 4 mil 800 casos de cor...
# 1                                    el pais catarsis
# 2   baja 23 incidencia delictiva en cdmx segun cif...
# 3   elizabeth hurley arrasa en instagram con bikin...
# 4           metafora 16 el fin de la historia oficial
# ..                                                ...
# 55  stassie karanikolau amiga de kylie jenner se l...
# 56  fer sagreeb el conductor mexicano que bajo 55 ...
# 57                 estado registra 84 muertes diarias
# 58  tu hermano ya no tenia pulmones el covid 19 se...
# 59  identidad oaxaquena llevo alan al jazz ahora e...
#
# [25 rows x 1 columns]

# %%
# Localizar los títulos faltantes y reemplazarlos por los localizados, usando loc

el_universal.loc[missing_titles_mask, 'title'] = missing_titles.loc[:, 'missing_titles']

el_universal
# Out:
#                                                  body  \
# 0   \nLa epidemia de coronavirus registró una nuev...
# 1   \nUna ola de acontecimientos concentrada en un...
# 2   \nLa Ciudad de México mostró una disminución d...
# 3   \nElizabeth Hurley presumió la impresionante f...
# 4   \n\nLos líderes autoritarios acostumbran cambi...
# ..                                                ...
# 69  \nLa fotografía es icónica. El día de la excar...
# 70  \nUna ola de acontecimientos concentrada en un...
# 71  \nLa élite que por generaciones monopolizó el ...
# 72  \n\nEn solidaridad con Nexos\n\n \n\nLa invest...
# 73  \n\nSuperado el berrinche de John Ackerman por...
#
#                                                 title  \
# 0   francia registra mas de 4 mil 800 casos de cor...
# 1                                    el pais catarsis
# 2   baja 23 incidencia delictiva en cdmx segun cif...
# 3   elizabeth hurley arrasa en instagram con bikin...
# ...

# %% [markdown]
# ## Clase #29 Additional cleanup

# %%
# 4. Añadir uid a las filas
import hashlib

uids = (el_universal
           .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
           .apply(lambda hash_object: hash_object.hexdigest())
       )

el_universal['uid'] = uids
el_universal.set_index('uid', inplace=True)
el_universal
# Out:
#                                                                                body  \
# uid
# 0f71df05a7f9137c0762b4e26fe2392d  \nLa epidemia de coronavirus registró una nuev...
# 66a000e4070d14a199e0346f0316b8db  \nUna ola de acontecimientos concentrada en un...
# 4b61e8cc7b9a6e601bbcc01a5bbb7023  \nLa Ciudad de México mostró una disminución d...
# 0778cbf7b127854354e3ef7051a8925a  \nElizabeth Hurley presumió la impresionante f...
# 71a9d826324711c50621cd56c18811ad  \n\nLos líderes autoritarios acostumbran cambi...
# ...                                                                             ...
# 96ae964f723e21b884b7e1c2c1039cd6  \nLa fotografía es icónica. El día de la excar...
# 66a000e4070d14a199e0346f0316b8db  \nUna ola de acontecimientos concentrada en un...
# 9325ab202ae8abce670ad657e232ca74  \nLa élite que por generaciones monopolizó el ...
# 7649225ff6f65789e372c3b138758d0e  \n\nEn solidaridad con Nexos\n\n \n\nLa invest...
# ...

# %%
stripped_body = (el_universal
                     .apply(lambda row: row['body'], axis=1)
                     .apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''), letters)))
                     .apply(lambda letters: ''.join(letters))
                )

stripped_body
# Out:
# uid
# 0f71df05a7f9137c0762b4e26fe2392d    La epidemia de coronavirus registró una nueva ...
# 66a000e4070d14a199e0346f0316b8db    Una ola de acontecimientos concentrada en una ...
# 4b61e8cc7b9a6e601bbcc01a5bbb7023    La Ciudad de México mostró una disminución de ...
# 0778cbf7b127854354e3ef7051a8925a    Elizabeth Hurley presumió la impresionante fig...
# 71a9d826324711c50621cd56c18811ad    Los líderes autoritarios acostumbran cambiar a...
#                                                           ...
# 96ae964f723e21b884b7e1c2c1039cd6    La fotografía es icónica. El día de la excarce...
# 66a000e4070d14a199e0346f0316b8db    Una ola de acontecimientos concentrada en una ...
# 9325ab202ae8abce670ad657e232ca74    La élite que por generaciones monopolizó el po...
# 7649225ff6f65789e372c3b138758d0e    En solidaridad con Nexos La investigación cont...
# 67a39a9eb39a56776190ca42dcd9f0ae    Superado el berrinche de John Ackerman por la ...
# Length: 74, dtype: object

# %%
el_universal['body'] = stripped_body

el_universal
# Out:
#                                                                                body  \
# uid
# 0f71df05a7f9137c0762b4e26fe2392d  La epidemia de coronavirus registró una nueva ...
# 66a000e4070d14a199e0346f0316b8db  Una ola de acontecimientos concentrada en una ...
# 4b61e8cc7b9a6e601bbcc01a5bbb7023  La Ciudad de México mostró una disminución de ...
# 0778cbf7b127854354e3ef7051a8925a  Elizabeth Hurley presumió la impresionante fig...
# 71a9d826324711c50621cd56c18811ad  Los líderes autoritarios acostumbran cambiar a...
# ...                                                                             ...
# 96ae964f723e21b884b7e1c2c1039cd6  La fotografía es icónica. El día de la excarce...
# 66a000e4070d14a199e0346f0316b8db  Una ola de acontecimientos concentrada en una ...
# 9325ab202ae8abce670ad657e232ca74  La élite que por generaciones monopolizó el po...
# 7649225ff6f65789e372c3b138758d0e  En solidaridad con Nexos La investigación cont...
# ...

# %% [markdown]
# ## Clase #31 Data enrichment

# %%
# 6 Tokenizar el título y el body

import nltk
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

# stop_words
el_universal
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/fertorresmx/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/fertorresmx/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                                                body  \
# uid
# 0f71df05a7f9137c0762b4e26fe2392d  La epidemia de coronavirus registró una nueva ...
# 66a000e4070d14a199e0346f0316b8db  Una ola de acontecimientos concentrada en una ...
# 4b61e8cc7b9a6e601bbcc01a5bbb7023  La Ciudad de México mostró una disminución de ...
# 0778cbf7b127854354e3ef7051a8925a  Elizabeth Hurley presumió la impresionante fig...
# 71a9d826324711c50621cd56c18811ad  Los líderes autoritarios acostumbran cambiar a...
# ...                                                                             ...
# 96ae964f723e21b884b7e1c2c1039cd6  La fotografía es icónica. El día de la excarce...
# ...

# %%
def tokenize_column(df, column_name):
    return (df
                .dropna()
                .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
                .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
                .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
                .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
                .apply(lambda valid_word_list: len(valid_word_list))
            )

el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')

el_universal
# Out:
#                                                                                body  \
# uid
# 0f71df05a7f9137c0762b4e26fe2392d  La epidemia de coronavirus registró una nueva ...
# 66a000e4070d14a199e0346f0316b8db  Una ola de acontecimientos concentrada en una ...
# 4b61e8cc7b9a6e601bbcc01a5bbb7023  La Ciudad de México mostró una disminución de ...
# 0778cbf7b127854354e3ef7051a8925a  Elizabeth Hurley presumió la impresionante fig...
# 71a9d826324711c50621cd56c18811ad  Los líderes autoritarios acostumbran cambiar a...
# ...                                                                             ...
# 96ae964f723e21b884b7e1c2c1039cd6  La fotografía es icónica. El día de la excarce...
# 66a000e4070d14a199e0346f0316b8db  Una ola de acontecimientos concentrada en una ...
# 9325ab202ae8abce670ad657e232ca74  La élite que por generaciones monopolizó el po...
# 7649225ff6f65789e372c3b138758d0e  En solidaridad con Nexos La investigación cont...
# ...

# %%
el_universal['n_tokens_body'] = tokenize_column(el_universal, 'body')

el_universal
# Out:
#                                                                                body  \
# uid
# 0f71df05a7f9137c0762b4e26fe2392d  La epidemia de coronavirus registró una nueva ...
# 66a000e4070d14a199e0346f0316b8db  Una ola de acontecimientos concentrada en una ...
# 4b61e8cc7b9a6e601bbcc01a5bbb7023  La Ciudad de México mostró una disminución de ...
# 0778cbf7b127854354e3ef7051a8925a  Elizabeth Hurley presumió la impresionante fig...
# 71a9d826324711c50621cd56c18811ad  Los líderes autoritarios acostumbran cambiar a...
# ...                                                                             ...
# 96ae964f723e21b884b7e1c2c1039cd6  La fotografía es icónica. El día de la excarce...
# 66a000e4070d14a199e0346f0316b8db  Una ola de acontecimientos concentrada en una ...
# 9325ab202ae8abce670ad657e232ca74  La élite que por generaciones monopolizó el po...
# 7649225ff6f65789e372c3b138758d0e  En solidaridad con Nexos La investigación cont...
# ...

# %% [markdown]
# ## Class #32 Duplicate values on Jupyter

# %%
el_universal['url'].value_counts()
# Out:
# https://www.eluniversal.com.mx/opinion/gaby-vargas/el-gozo-ii                                                   2
# https://www.eluniversal.com.mx/opinion/sara-sefchovich/metafora-16-el-fin-de-la-historia-oficial                2
# https://www.eluniversal.com.mx/opinion/francisco-valdes-ugalde/teoria-de-la-corrupcion                          2
# https://www.eluniversal.com.mx/opinion/lorenzo-meyer/una-oposicion-sin-cabeza                                   2
# https://www.eluniversal.com.mx/opinion/periodistas-el-universal/partidos-ahora-van-por-el-trife                 2
#                                                                                                                ..
# https://www.viveusa.mx/showbiz/elizabeth-hurley-arrasa-en-instagram-con-bikini-los-55-anos                      1
# https://www.eluniversal.com.mx/espectaculos/farandula/emmanuel-y-mijares-los-reyes-de-los-shows-en-streaming    1
# ...

# %%
el_universal['body'].value_counts()
# Out:
# En solidaridad con Nexos La investigación contra Emilio Lozoya es un episodio más de la saga del arraigado vicio de la corrupción. La historia de corrupción que nos presenta el gobierno tiene una estructura sencilla: el principal problema de México es la corrupción, ella se debe al “periodo neoliberal” y con la cuatroté se acabó con el problema. La versión embona “como anillo al dedo” con un país harto de la podredumbre y ansioso por creer en gobernantes que la trasciendan. Pero este cuento —ahora se le dice narrativa— está lleno de agujeros.1.¿Es el principal problema? Los temas adquieren jerarquía cuando la autoridad los coloca en la agenda pública y esta coincide con la percepción general. Para la población, la corrupción es el segundo problema más importante, después de la inseguridad según la ENCIG (https://bit.ly/2Qb5sRh) y su causa principal es la impunidad, la ausencia de sanciones y de castigos. Ahí están la narrativa y el espectáculo montado. Pero ¿tenemos las leyes e insti
# ...

# %%
el_universal['title'].value_counts()
# Out:
# Pronostican 130 mil muertes por Covid-19 en México al llegar a diciembre         1
# América busca sí o sí un defensa como refuerzo                                   1
# las peores tragedias en discotecas en america latina y el mundo                  1
# Rayados se impone al América en el Estadio Azteca                                1
# Chocolates, galletas, dulces, papas y botana con nuevo etiquetado                1
#                                                                                 ..
# ¡Bayern Munich, campeón de la Champions League!                                  1
# El récord que podría romper Keylor Navas en la final de la Champions League      1
# Señales que indican que debes cambiar la batería de tu celular                   1
# Miguel Herrera lanza ultimátum: Quien no entienda donde está parado, no juega    1
# tu hermano ya no tenia pulmones el covid 19 se los comio                         1
# Name: title, Length: 74, dtype: int64

# %%
el_universal[el_universal['title']== 'Selena Gomez muestra en video los tristes estragos del lupus']
# Out:
#                                                                                body  \
# uid
# f1e155d66ab552a6a3f98799f2d86abe  Los fans de Selena Gomez se conmovieron luego ...
#
#                                                                               title  \
# uid
# f1e155d66ab552a6a3f98799f2d86abe  Selena Gomez muestra en video los tristes estr...
#
#                                                                                 url  \
# uid
# f1e155d66ab552a6a3f98799f2d86abe  https://www.eluniversal.com.mx/espectaculos/se...
#
#                                  newspaper_uid                    host  \
# uid
# f1e155d66ab552a6a3f98799f2d86abe   eluniversal  www.eluniversal.com.mx
#
#                                   n_tokens_title  n_tokens_body
# uid
# f1e155d66ab552a6a3f98799f2d86abe               7            224

# %%
el_universal.drop_duplicates(subset=['title'], keep='first', inplace=True)

# %%
el_universal.drop_duplicates(subset=['body'], keep='first', inplace=True)

# %% [markdown]
# ## Final table

# %%
el_universal
# Out:
#                                                                                body  \
# uid
# 0f71df05a7f9137c0762b4e26fe2392d  La epidemia de coronavirus registró una nueva ...
# 66a000e4070d14a199e0346f0316b8db  Una ola de acontecimientos concentrada en una ...
# 4b61e8cc7b9a6e601bbcc01a5bbb7023  La Ciudad de México mostró una disminución de ...
# 0778cbf7b127854354e3ef7051a8925a  Elizabeth Hurley presumió la impresionante fig...
# 71a9d826324711c50621cd56c18811ad  Los líderes autoritarios acostumbran cambiar a...
# ...                                                                             ...
# e9834f1d3706bdb2c5acf703df7ecba3  Aunque Alan Villanueva Díaz, nació en la capit...
# bf66f7fc393e6920634b7a527428603e  La jefa de Gobierno de la Ciudad de México, Cl...
# c99be6ee41488067f706ee4bafa186ae  El Festival Internacional Cervantino anunció l...
# e4f9403218572077a6327efa8735bff5  El cubrebocas es ya una prenda necesaria para ...
# ...

# %% [markdown]
# ## Class 34 Descriptive analysis

# %%
clean_eluniversal = pd.read_csv('web_scrapper_curso_data_eng/clean_eluniversal_2020_08_23x_articles.csv')
clean_elpais = pd.read_csv('web_scrapper_curso_data_eng/clean_elpais_2020_08_23_articles.csv')

# %%
clean_eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       74.000000      74.000000
# mean         5.378378     262.432432
# std          2.291752     142.549879
# min          1.000000      64.000000
# 25%          4.000000     167.250000
# 50%          6.000000     240.000000
# 75%          7.000000     309.000000
# max         10.000000     887.000000

# %%
clean_elpais.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       62.000000      62.000000
# mean         6.048387     591.854839
# std          2.795942     602.925895
# min          1.000000       7.000000
# 25%          4.000000     259.250000
# 50%          6.000000     447.500000
# 75%          8.000000     699.250000
# max         13.000000    3494.000000

# %%
clean_elpais.loc[clean_elpais['n_tokens_title'] == 1]
# Out:
#                                  uid  \
# 5   9e5e81ac8191e01b63581176d3262132
# 42  52cd2ff7451d75a7018c73c39429b628
#
#                                                  body        title  \
# 5   ENRIQUE FLORESUno. Un buen amigo mío murió al ...  Mis amigos
# 42  El ministro de Defensa de Colombia, Carlos Hol...     Masacres
#
#                                                   url newspaper_uid  \
# 5   https://www.elpais.com/opinion/2020-08-21/mis-...        elpais
# 42  https://www.elpais.com/opinion/2020-08-23/masa...        elpais
#
#               host  n_tokens_title  n_tokens_body
# 5   www.elpais.com               1             70
# 42  www.elpais.com               1             75

# %%
clean_eluniversal.loc[clean_eluniversal['n_tokens_title'] == 1]
# Out:
#                                  uid  \
# 7   9abd25de41fb277f2f0deaf935c4697f
# 68  9abd25de41fb277f2f0deaf935c4697f
#
#                                                  body    title  \
# 7   Las vacunas son una de las grandes invenciones...  vacunas
# 68  Las vacunas son una de las grandes invenciones...  Vacunas
#
#                                                   url newspaper_uid  \
# 7   https://www.eluniversal.com.mx/opinion/arnoldo...   eluniversal
# 68  https://www.eluniversal.com.mx/opinion/arnoldo...   eluniversal
#
#                       host  n_tokens_title  n_tokens_body
# 7   www.eluniversal.com.mx               1            322
# 68  www.eluniversal.com.mx               1            322

# %%
# %matplotlib inline

# %%
clean_elpais['n_tokens_title'].plot(style = 'k.')
clean_eluniversal['n_tokens_title'].plot(style = 'r.')

# %%
clean_elpais['n_tokens_body'].plot(style = 'k.')
clean_eluniversal['n_tokens_body'].plot(style = 'r.')

# %%
all_newspapers = pd.concat([clean_eluniversal, clean_elpais])

grouped = all_newspapers.groupby('newspaper_uid')
grouped.hist()
# Out:
# newspaper_uid
# elpais         [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min', 'mean', 'max'])
# Out:
#                min        mean   max
# newspaper_uid
# elpais           7  591.854839  3494
# eluniversal     64  262.432432   887

# %%
grouped.plot()
# Out:
# newspaper_uid
# elpais         AxesSubplot(0.125,0.125;0.775x0.755)
# eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
